# %% [markdown]
# # Actividad 9
# # 🔍 Parte 2: Análisis de Datasets
# Objetivo: Analizar datasets con Pandas, utilizando filtros y visualización con:
# * tablas
# * gráficos
# * mapas

# %% [markdown]
# ## Elegí un dataset
# * Realizar exploración básica

# %% [markdown]
# *  ### Avistajes de felinos en Argentina
#     * Link para descarga: https://archivos.linti.unlp.edu.ar/index.php/s/5iC9FrYWiGi11d0
#     * Nombre del archivo: felinos_filtrado.csv
#     * Descargado y adaptado de: https://www.gbif.org/
#     * Descripción: describe los avistajes de felinos en peligro de extinción con ubicación, especie, fecha etc.
# * ### Áreas protegidas
#     * Link para descarga: https://archivos.linti.unlp.edu.ar/index.php/s/Eqw1eAVC1pdefmb
#     * Descargado de: https://dnsg.ign.gob.ar/apps/api/v1/capas-sig/Geodesia+y+demarcaci%C3%B3n/L%C3%ADmites/area_protegida/csv*
#     * Página consultada: https://www.ign.gob.ar/NuestrasActividades/InformacionGeoespacial/CapasSIG
#     * Descripción: detalle de las áreas protegidas terrestres y marítimas
#     * Documento con detalle de los datos: https://archivos.linti.unlp.edu.ar/index.php/s/9LoXcqzxI8bDzbN
# * ### Aeropuertos Argentina
#     * Link para  descarga: https://archivos.linti.unlp.edu.ar/index.php/s/TYVZ5U6HC457M1k
#     * Nombre del archivo: ar-airports.csv
#     * Descargado de: https://ourairports.com/countries/AR/airports.csv
#     * Descripción: Aeropuertos de Argentina por tipo y localidad
# * ### Conectividad Argentina
#     * Link para descarga: https://archivos.linti.unlp.edu.ar/index.php/s/3k2TO5sSzaAU6IY
#     * Nombre del archivo: Conectividad_Internet.csv
#     * Descargado de : https://datos.gob.ar/dataset/enacom-conectividad-al-servicio-internet/archivo/enacom_CONEC-AL-SERVI-DE-INTER_0
#     * Descripción: Describe las tecnologías disponibles en las localidades para acceder al servicio de Internet fijo y móvil
# * ### Precios combustibles
#     * [Link para descarga](https://archivos.linti.unlp.edu.ar/index.php/s/x0InilFLhgt1B1R).
#     * Descargado de: https://www.datos.gob.ar/dataset/energia-precios-surtidor---resolucion-3142016
#     * Descripción: Datos del Sistema en línea de información de precios de combustibles en surtidor, a través del cual los titulares de bocas de expendio de combustibles líquidos inscriptos en el registro creado por la resolución n° 1.102/2004 presentan la información relativa a precios de comercialización minorista dentro de las 8 (ocho) horas de producida una modificación en el precio en surtidor.
# * ### Ferrocarriles.
#     *  [Link para descarga](https://archivos.linti.unlp.edu.ar/index.php/s/Pr6vcKL9fxfmZoj)
#     * Descargado de :https://datos.transporte.gob.ar/dataset/cruces-ferroviarios
#     * Descripción: Cruces ferroviarios con respecto a la red vial nacional. Relevados por la Dirección Nacional de Vialidad. Año 2016.

# %%
Duarte ALejo eligió Aeropuertos

# %%
import pandas as pd
import plotly.express as pl
import folium as fo

aeropuertos=pd.read_csv("ar-airports.csv")

# %% [markdown]
# # ✅ Etapa 1: Exploración Básica (10 min)
# * Cantidad de filas y columans
# * Nombres de las columnas
# * Tipos de datos de las columnas
# * Ver las primeras 10 filas del dataset

# %%
CantFilCol = list(aeropuertos.shape)

print("Este dataset tiene", CantFilCol[0], "Filas y", CantFilCol[1], "Columnas")
print("Sus nombres y tipo son", aeropuertos.dtypes)
print("Sus primeras 10 filas son: ")
aeropuertos.head(10)
# Out:
# Este dataset tiene 956 Filas y 24 Columnas
# Sus nombres y tipo son id                     int64
# ident                 object
# type                  object
# name                  object
# latitude_deg         float64
# longitude_deg        float64
# elevation_ft         float64
# continent             object
# country_name          object
# iso_country           object
# region_name           object
# iso_region            object
# local_region          object
# municipality          object
# scheduled_service      int64
# gps_code              object
# icao_code             object
# iata_code             object
# local_code            object
# home_link             object
# wikipedia_link        object
# keywords              object
# score                  int64
# last_updated          object
# dtype: object
# Sus primeras 10 filas son:
#      id    ident            type  \
# 0  5781     SAEZ   large_airport
# 1  5771     SABE   large_airport
# 2  5835     SAWH  medium_airport
# 3  5806     SARI  medium_airport
# 4  5831     SAWC  medium_airport
# 5  5786     SAME  medium_airport
# 6  5852     SAZS  medium_airport
# 7  5811     SASA  medium_airport
# 8  5773     SACO  medium_airport
# 9    37  AR-0742          closed
#
#                                                 name  latitude_deg  \
# 0           Minister Pistarini International Airport    -34.822200
# 1                              Jorge Newbery Airpark    -34.559200
# 2  Ushuaia - Malvinas Argentinas International Ai...    -54.843300
# 3         Cataratas Del Iguazú International Airport    -25.737301
# 4  El Calafate - Commander Armando Tola Internati...    -50.280300
# 5                              El Plumerillo Airport    -32.831699
# 6                    San Carlos de Bariloche Airport    -41.151199
# 7      Martin Miguel De Guemes International Airport    -24.856001
# 8               Ingeniero Ambrosio Taravella Airport    -31.323601
# 9                            Colonia Catriel Airport    -37.910198
#
#    longitude_deg  elevation_ft continent country_name iso_country  ...  \
# 0     -58.535800          67.0        SA    Argentina          AR  ...
# 1     -58.415600          18.0        SA    Argentina          AR  ...
# 2     -68.295800         102.0        SA    Argentina          AR  ...
# 3     -54.473400         916.0        SA    Argentina          AR  ...
# 4     -72.053101         669.0        SA    Argentina          AR  ...
# 5     -68.792900        2310.0        SA    Argentina          AR  ...
# 6     -71.157501        2774.0        SA    Argentina          AR  ...
# 7     -65.486198        4088.0        SA    Argentina          AR  ...
# 8     -64.208000        1604.0        SA    Argentina          AR  ...
# 9     -67.834999        1026.0        SA    Argentina          AR  ...
#
#   scheduled_service gps_code icao_code iata_code  local_code  \
# 0                 1     SAEZ      SAEZ       EZE         EZE
# 1                 1     SABE      SABE       AEP         AER
# 2                 1     SAWH      SAWH       USH         USU
# 3                 1     SARI      SARI       IGR         IGU
# 4                 1     SAWC       NaN       FTE         ECA
# 5                 1     SAME      SAME       MDZ         DOZ
# 6                 1     SAZS      SAZS       BRC         BAR
# 7                 1     SASA      SASA       SLA         SAL
# 8                 1     SACO      SACO       COR         CBA
# 9                 0      NaN       NaN       NaN         NaN
#
#                                  home_link  \
# 0       http://www.aa2000.com.ar/index.php
# 1                                      NaN
# 2                                      NaN
# 3          http://www.aa2000.com.ar/iguazu
# 4  http://www.aeropuertoelcalafate.com/en/
# 5                                      NaN
# 6       http://www.aa2000.com.ar/bariloche
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
#
#                                       wikipedia_link  \
# 0  https://en.wikipedia.org/wiki/Ministro_Pistari...
# 1  https://en.wikipedia.org/wiki/Aeroparque_Jorge...
# 2  https://en.wikipedia.org/wiki/Ushuaia_%E2%80%9...
# 3  https://en.wikipedia.org/wiki/Cataratas_del_Ig...
# 4  https://en.wikipedia.org/wiki/Comandante_Arman...
# 5  https://en.wikipedia.org/wiki/Governor_Francis...
# 6  https://en.wikipedia.org/wiki/San_Carlos_de_Ba...
# 7  https://en.wikipedia.org/wiki/Mart%C3%ADn_Migu...
# 8  https://en.wikipedia.org/wiki/Ingeniero_Ambros...
# 9  https://en.wikipedia.org/wiki/Colonia_Catriel_...
#
#                      keywords score               last_updated
# 0                 BUE, Ezeiza  1275  2022-10-27T15:05:29+00:00
# 1                         NaN  1050  2021-10-07T15:55:36+00:00
# 2                         NaN   750  2025-03-22T20:48:42+00:00
# 3                      Iguaçu   750  2018-09-13T12:34:47+00:00
# 4                         NaN   500  2022-01-12T18:23:15+00:00
# 5                         NaN   750  2011-02-17T01:49:01+00:00
# 6    Teniente Luis Candelaria   750  2025-03-09T01:30:49+00:00
# 7                         NaN   750  2011-07-03T00:07:47+00:00
# 8                         NaN   750  2019-04-15T20:31:25+00:00
# 9  SA30, SA0U, SA30, CCT, CLT    50  2025-02-25T14:37:41+00:00
#
# [10 rows x 24 columns]

# %% [markdown]
# # ✅ Etapa 2: Análisis por temática(10 min)
# * Cada dataset se analizará según categorías correspondiente a los datos que lo conforman

# %%
print(aeropuertos['type'].unique())
print(aeropuertos['type'].value_counts())
print(aeropuertos['local_code'].value_counts())
# Out:
# ['large_airport' 'medium_airport' 'closed' 'small_airport' 'heliport'
#  'balloonport']
# type
# small_airport     694
# heliport          148
# medium_airport     69
# closed             42
# large_airport       2
# balloonport         1
# Name: count, dtype: int64
# local_code
# HSN    2
# ROH    2
# RAW    1
# RLC    1
# RES    1
#       ..
# BOG    1
# ACB    1
# EML    1
# DOR    1
# TIR    1
# Name: count, Length: 769, dtype: int64

# %% [markdown]
# # ✅ Etapa 3: Filtrar y Limpiar Datos (15 min)

# %% [markdown]
# # ✅ Etapa 4: Valores Nulos y Estadísticas (10 min)
# * Mostrar la composición de las columnas indicando aquellas con datos faltantes

# %%
aeropuertos.describe()
aeropuertos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956 entries, 0 to 955
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 956 non-null    int64
#  1   ident              956 non-null    object
#  2   type               956 non-null    object
#  3   name               956 non-null    object
#  4   latitude_deg       956 non-null    float64
#  5   longitude_deg      956 non-null    float64
#  6   elevation_ft       923 non-null    float64
#  7   continent          956 non-null    object
#  8   country_name       956 non-null    object
#  9   iso_country        956 non-null    object
#  10  region_name        956 non-null    object
#  11  iso_region         956 non-null    object
#  12  local_region       956 non-null    object
#  13  municipality       941 non-null    object
#  14  scheduled_service  956 non-null    int64
#  15  gps_code           228 non-null    object
#  16  icao_code          93 non-null     object
#  17  iata_code          103 non-null    object
#  18  local_code         771 non-null    object
#  19  home_link          14 non-null     object
#  20  wikipedia_link     186 non-null    object
#  21  keywords           119 non-null    object
#  22  score              956 non-null    int64
#  23  last_updated       956 non-null    object
# dtypes: float64(3), int64(3), object(18)
# memory usage: 179.4+ KB

# %% [markdown]
# # ✅ Etapa 5: Visualización con Mapas (15 min)

# %% [markdown]
# *  ### Avistajes de felinos en Argentina
#     * **Mapa**: mostrar iconos de color según el tipo de "genus" .
# * ### Áreas protegidas
#     * **Mapa**: mostrar iconos de color según el tipo de área protegida definida en la columna "tap" que indica (Parque, Reserva, MonumentosNatural).
# * ### Aeropuertos Argentina
#     * **Mapa**: mostrar iconos de color según el tipo de aeropuerto: type
# * ### Conectividad Argentina
#     * **Mapa**: mostrar las localidades donde hay FIBRAOPTICA.
# * ### Precios combustibles
#     *  **Mapa**: mostrar los registros de las provincias de la Patagonia según "tipohorario".
# * ### Ferrocarriles.
#     * **Mapa**: mostrar las estaciones en el mapa según el tipo indicado en la columna "gna".

# %% [markdown]
# ## 📌 Paso 1.Generar un mapa **base** para luego agregar los puntos

# %%
def genMap():
    attr = (
        '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> '
        'contributors, &copy; <a href="https://cartodb.com/attributions">CartoDB</a>'
    )

    tiles = 'https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png'
    m = fo.Map(
        location=(-33.457606, -65.346857),
        control_scale=True,
        zoom_start=5,
        name='es',
        tiles=tiles,
        attr=attr
    )
    return m

# %%
mapa=genMap()

# %% [markdown]
# ## 📌 Paso 2. Definir la función para  agregar los puntos

# %%
def agregarMark(row):
    colores = {'small_airport': 'red', 'medium_airport': 'yellow', 'large_airport': 'green', 'heliport' : 'blue'}
    color = colores.get(row['type'], 'gray')
    fo.CircleMarker(
        location=[row['latitude_deg'], row['longitude_deg']],
        radius=6,
        color=color,
        fill=True,
        popup=row['name']
        ).add_to(mapa)

# %% [markdown]
# ## 📌 Paso 3. Agrergar los puntos al mapa

# %%
aeropuertos.apply(agregarMark, axis=1)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61274e4417de2c7a04d3748c6606490a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61274e4417de2c7a04d3748c6606490a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_61274e4417de2c7a04d3748c6606490a = L.map(
#                 &quot;map_61274e4417de2c7a04d3748c6606490a&quot;,
#                 {
#                     center: [-33.457606, -65.346857],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;name&quot;: &quot;es&quot;,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_61274e4417de2c7a04d3748c6606490a);
#
#
#
#
#
#             var tile_layer_08a194a3f11eb2c01190c9a1c4d4d68e = L.tileLayer(
#                 &quot;https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u0026copy; \u003ca href=\&quot;https://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_08a194a3f11eb2c01190c9a1c4d4d68e.addTo(map_61274e4417de2c7a04d3748c6606490a);
#
#
#             var circle_marker_53928f1f94d9ac659daacb25f769c687 = L.circleMarker(
#                 [-34.8222, -58.5358],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_61274e4417de2c7a04d3748c6606490a);
#
#
#         var popup_327947493a6bc766a37d58a48ba05bb7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5843f879288c595f47a2e1e154de107d = $(`&lt;div id=&quot;html_5843f879288c595f47a2e1e154de107d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Minister Pistarini International Airport&lt;/div&gt;`)[0];
#                 popup_327947493a6bc766a37d58a48ba05bb7.setContent(html_5843f879288c595f47a2e1e154de107d);
#
#
#
#         circle_marker_53928f1f94d9ac659daacb25f769c687.bindPopup(popup_327947493a6bc766a37d58a48ba05bb7)
#         ;
#
#
#
#
#             var circle_marker_b3c87423f68054ef80ed845528c75721 = L.circleMarker(
#                 [-34.5592, -58.4156],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_61274e4417de2c7a04d3748c6606490a);
#
#
#         var popup_ad16b8840518253d60e364e215817476 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fbfbe344f8447b80ef685d662a1ccd4 = $(`&lt;div id=&quot;html_4fbfbe344f8447b80ef685d662a1ccd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jorge Newbery Airpark&lt;/div&gt;`)[0];
#                 popup_ad16b8840518253d60e364e215817476.setContent(html_4fbfbe344f8447b80ef685d662a1ccd4);
#
#
#
#         circle_marker_b3c87423f68054ef80ed845528c75721.bindPopup(popup_ad16b8840518253d60e364e215817476)
#         ;
#
#
#
#
#             var circle_marker_f8dd51cee69366f86d8de76166e889d1 = L.circleMarker(
#                 [-54.8433, -68.2958],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_61274e4417de2c7a04d3748c6606490a);
#
#
#         var popup_7f6202fafe9eb8a7bc9e60d0a0233414 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75dd6addea125fcd3c657186af53255a = $(`&lt;div id=&quot;html_75dd6addea125fcd3c657186af53255a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ushuaia - Malvinas Argentinas International Airport&lt;/div&gt;`)[

# %%
print("Puertos y Aeropuertos de Santa Cruz:")
aeropuertos[aeropuertos["region_name"]=="Santa Cruz Province"]
# Out:
# Aeropuertos de Santa Cruz:
#          id    ident            type  \
# 4      5831     SAWC  medium_airport
# 10     5834     SAWG  medium_airport
# 16     5836     SAWJ  medium_airport
# 33     5832     SAWD  medium_airport
# 34     5839     SAWU  medium_airport
# ..      ...      ...             ...
# 899   42898  AR-0476        heliport
# 901   42896  AR-0474        heliport
# 903   42897  AR-0475        heliport
# 911  340028  AR-0665        heliport
# 934  348452  AR-0686          closed
#
#                                                   name  latitude_deg  \
# 4    El Calafate - Commander Armando Tola Internati...    -50.280300
# 10                   Piloto Civil N. Fernández Airport    -51.608900
# 16                    Capitan D Daniel Vazquez Airport    -49.306816
# 33                              Puerto Deseado Airport    -47.735300
# 34                                  Santa Cruz Airport    -50.016500
# ..                                                 ...           ...
# 899        Heliplataforma Equipo Modular M-10 Heliport    -52.548900
# 901             Heliplataforma Barcaza Yagana Heliport    -52.522500
# 903     Heliplataforma Buque Skandi Patagonia Heliport    -52.000000
# 911                 Heliplataforma Móvil Ocean Scepter    -46.466667
# 934                              Río Gallegos Air Base    -51.648610
#
#      longitude_deg  elevation_ft continent country_name iso_country  ...  \
# 4       -72.053101         669.0        SA    Argentina          AR  ...
# 10      -69.312600          61.0        SA    Argentina          AR  ...
# 16      -67.802596         203.0        SA    Argentina          AR  ...
# 33      -65.904100         268.0        SA    Argentina          AR  ...
# 34      -68.579200         364.0        SA    Argentina          AR  ...
# ..             ...           ...       ...          ...         ...  ...
# 899     -68.311900         108.0        SA    Argentina          AR  ...
# 901     -68.280600          49.0        SA    Argentina          AR  ...
# 903     -67.000000           NaN        SA    Argentina          AR  ...
# 911     -67.433333         505.0        SA    Argentina          AR  ...
# 934     -69.203140          56.0        SA    Argentina          AR  ...
#
#     scheduled_service gps_code icao_code iata_code  local_code  \
# 4                   1     SAWC       NaN       FTE         ECA
# 10                  1     SAWG      SAWG       RGL         GAL
# 16                  0     SAWJ      SAWJ       ULA         SJU
# 33                  1     SAWD      SAWD       PUD         ADO
# 34                  0     SAWU      SAWU       RZA         SCZ
# ..                ...      ...       ...       ...         ...
# 899                 0      NaN       NaN       NaN         HEM
# 901                 0      NaN       NaN       NaN         HBY
# 903                 0      NaN       NaN       NaN         HSP
# 911                 0      NaN       NaN       NaN         HOS
# 934                 0      NaN       NaN       NaN         NaN
#
#                                    home_link  \
# 4    http://www.aeropuertoelcalafate.com/en/
# 10                                       NaN
# 16                                       NaN
# 33                                       NaN
# 34                                       NaN
# ..                                       ...
# 899                                      NaN
# 901                                      NaN
# 903                                      NaN
# 911                                      NaN
# 934                                      NaN
#
#                                         wikipedia_link  \
# 4    https://en.wikipedia.org/wiki/Comandante_Arman...
# 10   https://en.wikipedia.org/wiki/Piloto_Civil_Nor...
# 16   https://en.wikipedia.org/wiki/Capit%C3%A1n_Jos...
# 33   https://en.wikipedia.org/wiki/Puerto_Deseado_A...
# 34   https://en.wikipedia.org/wiki/Santa_Cruz_Airpo...
# ..                                                 ...
# 899                                                NaN
# 901                                                NaN
# 903                                                NaN
# 911                                                NaN
# 934                                                NaN
#
#                            keywords score               last_updated
# 4                               NaN   500  2022-01-12T18:23:15+00:00
# 10   Brigadier General D. A. Parodi   750  2011-02-13T13:44:01+00:00
# 16                              NaN   750  2025-02-05T15:21:04+00:00
# 33                              NaN   750  2023-05-01T17:23:28+00:00
# 34                              NaN   750  2025-02-05T15:20:33+00:00
# ..                              ...   ...                        ...
# 899                             NaN     0  2009-10-20T11:13:21+00:00
# 901                             NaN     0  2009-10-20T11:13:21+00:00
# 903                             NaN     0  2009-10-20T11:13:21+00:00
# 911                             NaN     0  2021-01-22T10:22:35+00:00
# 934                             NaN     0  2021-10-07T12:06:42+00:00
#
# [75 rows x 24 columns]

# %%
aeropuertos['region_name'].value_counts()
aedeco=aeropuertos[aeropuertos["region_name"] == "Córdoba Province"]
aedeco
# Out:
#          id    ident            type  \
# 8      5773     SACO  medium_airport
# 43    29806     SACD   small_airport
# 58       17     SA05   small_airport
# 61    29803     SACE   small_airport
# 78     5796     SAOC  medium_airport
# ..      ...      ...             ...
# 892   38958  AR-0283        heliport
# 908   42889  AR-0467        heliport
# 909  318510  AR-0572        heliport
# 952   42893  AR-0471        heliport
# 954   42903  AR-0481        heliport
#
#                                                   name  latitude_deg  \
# 8                 Ingeniero Ambrosio Taravella Airport    -31.323601
# 43                              Coronel Olmedo Airport    -31.487499
# 58                                  Bell Ville Airport    -32.659900
# 61   Escuela de Aviación Militar (Military Aviation...    -31.444223
# 78                            Area De Material Airport    -33.085098
# ..                                                 ...           ...
# 892                         Norberto Cordeiro Heliport    -31.414200
# 908                                   Berrini Heliport    -31.439700
# 909                Centro Cívico Bicentenario Heliport    -31.420370
# 952  Dayry Partners Americas Manufacturing Argentin...    -32.440000
# 954                                      Roca Heliport    -32.060000
#
#      longitude_deg  elevation_ft continent country_name iso_country  ...  \
# 8       -64.208000        1604.0        SA    Argentina          AR  ...
# 43      -64.141403        1416.0        SA    Argentina          AR  ...
# 58      -62.702000         429.0        SA    Argentina          AR  ...
# 61      -64.283377        1646.0        SA    Argentina          AR  ...
# 78      -64.261299        1380.0        SA    Argentina          AR  ...
# ..             ...           ...       ...          ...         ...  ...
# 892     -64.496900        2036.0        SA    Argentina          AR  ...
# 908     -64.343300        1811.0        SA    Argentina          AR  ...
# 909     -64.173235        1306.0        SA    Argentina          AR  ...
# 952     -63.228900         639.0        SA    Argentina          AR  ...
# 954     -64.779400        3444.0        SA    Argentina          AR  ...
#
#     scheduled_service gps_code icao_code iata_code  local_code home_link  \
# 8                   1     SACO      SACO       COR         CBA       NaN
# 43                  0     SACD       NaN       NaN         EDO       NaN
# 58                  0     SA05       NaN       NaN         BEL       NaN
# 61                  0     SACE       NaN       NaN         ESC       NaN
# 78                  0     SAOC      SAOC       RCU         TRC       NaN
# ..                ...      ...       ...       ...         ...       ...
# 892                 0      NaN       NaN       NaN         HAI       NaN
# 908                 0      NaN       NaN       NaN         HBR       NaN
# 909                 0      NaN       NaN       NaN         HBI       NaN
# 952                 0      NaN       NaN       NaN         HNE       NaN
# 954                 0      NaN       NaN       NaN         HYC       NaN
#
#                                         wikipedia_link keywords score  \
# 8    https://en.wikipedia.org/wiki/Ingeniero_Ambros...      NaN   750
# 43   https://en.wikipedia.org/wiki/Coronel_Olmedo_A...      NaN    50
# 58                                                 NaN     SA05    50
# 61   https://en.wikipedia.org/wiki/Escuela_de_Aviac...      NaN    50
# 78   https://en.wikipedia.org/wiki/Las_Higueras_Air...      NaN   375
# ..                                                 ...      ...   ...
# 892                                                NaN      NaN    25
# 908                                                NaN      NaN     0
# 909                                                NaN      NaN     0
# 952                                                NaN      NaN     0
# 954                                                NaN      NaN     0
#
#                   last_updated
# 8    2019-04-15T20:31:25+00:00
# 43   2024-05-18T21:35:09+00:00
# 58   2009-10-20T11:12:52+00:00
# 61   2024-05-18T21:35:29+00:00
# 78   2024-05-19T23:13:19+00:00
# ..                         ...
# 892  2009-10-20T11:13:17+00:00
# 908  2009-10-20T11:13:21+00:00
# 909  2016-06-11T23:48:41+00:00
# 952  2009-10-20T11:13:21+00:00
# 954  2009-10-20T11:13:21+00:00
#
# [100 rows x 24 columns]

# %%
aedesa=aeropuertos[aeropuertos["region_name"] == "Salta Province"]
aedesa
# Out:
#          id    ident            type  \
# 7      5811     SASA  medium_airport
# 51     5815     SAST  medium_airport
# 138      30     SA22   small_airport
# 164    5813     SASO  medium_airport
# 183   42841  AR-0419   small_airport
# 218  318241  AR-0514   small_airport
# 236      13     SA01   small_airport
# 237      14     SA02   small_airport
# 362  318253  AR-0525   small_airport
# 390  318254  AR-0526   small_airport
# 405   42846  AR-0424   small_airport
# 408  553521  AR-0738   small_airport
# 412  318255  AR-0527   small_airport
# 472   38887  AR-0212   small_airport
# 509  318265  AR-0534   small_airport
# 559   38948  AR-0273   small_airport
# 585  318271  AR-0539   small_airport
# 601  327644  AR-0640   small_airport
# 608  318276  AR-0543   small_airport
# 609  327621  AR-0634   small_airport
# 663   41545     SASR   small_airport
# 672   38995  AR-0320   small_airport
# 872   38768  AR-0093        heliport
# 873   38834  AR-0159        heliport
# 874   38869  AR-0194        heliport
# 940  560398  AR-0740        heliport
#
#                                               name  latitude_deg  \
# 7    Martin Miguel De Guemes International Airport    -24.856001
# 51                 General Enrique Mosconi Airport    -22.616877
# 138                         Santa Victoria Airport    -22.285700
# 164                                   Orán Airport    -23.152800
# 183                      Finca La Frontera Airport    -22.123510
# 218                           Finca Cuchuy Airport    -23.040000
# 236                                  Cachi Airport    -25.105000
# 237                               Cafayate Airport    -26.056101
# 362                                Salvita Airport    -23.212800
# 390                                     El Desafio    -23.242600
# 405                       General Belgrano Airport    -24.745834
# 408                    Ingenio San Isidro airstrip    -24.684730
# 412                      Finca La Hercilia Airport    -22.614700
# 472             Agropecuaria Rio Juramento Airport    -25.186701
# 509                         AeroSoluciones Airport    -24.748890
# 559                                  Metán Airport    -25.514400
# 585                          Finca Toloche Airport    -25.434600
# 601                      Pichanal-Franzini Airport    -23.338946
# 608                   SAS Aeroaplicaciones Airport    -24.806670
# 609                       Finca Porvenir 8 Airport    -24.994562
# 663                              Rivadavia Airport    -24.188601
# 672                 Rosario De La Frontera Airport    -25.828056
# 872             Centro Cívico Grand Bourg Heliport    -24.780600
# 873                      Finca Las Costas Heliport    -24.770300
# 874                   Hospital De Milagro Heliport    -24.773100
# 940                                  Temet Helipad    -24.836242
#
#      longitude_deg  elevation_ft continent country_name iso_country  ...  \
# 7       -65.486198        4088.0        SA    Argentina          AR  ...
# 51      -63.793015        1472.0        SA    Argentina          AR  ...
# 138     -62.713699         918.0        SA    Argentina          AR  ...
# 164     -64.329201        1171.0        SA    Argentina          AR  ...
# 183     -63.290550         160.0        SA    Argentina          AR  ...
# 218     -63.721100         928.0        SA    Argentina          AR  ...
# 236     -66.157204        8232.0        SA    Argentina          AR  ...
# 237     -65.936897        5375.0        SA    Argentina          AR  ...
# 362     -64.033900         928.0        SA    Argentina          AR  ...
# 390     -63.323000         800.0        SA    Argentina          AR  ...
# 405     -65.418892        4136.0        SA    Argentina          AR  ...
# 408     -65.017047         695.0        SA    Argentina          AR  ...
# 412     -63.662759        1227.0        SA    Argentina          AR  ...
# 472     -64.082802        1184.0        SA    Argentina          AR  ...
# 509     -64.235000        1614.0        SA    Argentina          AR  ...
# 559     -64.965599        2765.0        SA    Argentina          AR  ...
# 585     -63.857800        1040.0        SA    Argentina          AR  ...
# 601     -64.247126        1004.0        SA    Argentina          AR  ...
# 608     -64.181110        1498.0        SA    Argentina          AR  ...
# 609     -64.341664        1732.0        SA    Argentina          AR  ...
# 663     -62.883400         679.0        SA    Argentina          AR  ...
# 672     -64.968056        2746.0        SA    Argentina          AR  ...
# 872     -65.451400        4132.0        SA    Argentina          AR  ...
# 873     -65.495600        4300.0        SA    Argentina          AR  ...
# 874     -65.415600        4068.0        SA    Argentina          AR  ...
# 940     -65.372347        3871.0        SA    Argentina          AR  ...
#
#     scheduled_service gps_code icao_code iata_code  local_code  \
# 7                   1     SASA      SASA       SLA         SAL
# 51                  0     SAST      SAST       TTG         TAR
# 138                 0     SA22       NaN       NaN         VIT
# 164                 0     SASO      SASO       ORA         ORA
# 183                 0      NaN       NaN       NaN         SMF
# 218                 0      NaN       NaN       NaN         FCU
# 236                 0     SA01       NaN       NaN         CCS
# 237                 0      NaN       NaN       NaN         CAF
# 362                 0      NaN       NaN       NaN         SLV
# 390                 0      NaN       NaN       NaN         FDD
# 405                 0      NaN       NaN       NaN         GBL
# 408                 0      NaN       NaN       NaN         NaN
# 412                 0      NaN       NaN       NaN         FLH
# 472                 0      NaN       NaN       NaN         JGA
# 509                 0      NaN       NaN       NaN         LLA
# 559                 0     SASM       NaN       NaN         MTN
# 585                 0      NaN       NaN       NaN         NST
# 601                 0      NaN       NaN       NaN        2105
# 608                 0      NaN       NaN       NaN         PCA
# 609                 0      NaN       NaN       NaN        2800
# 663                 0     SASR       NaN       NaN         RIV
# 672                 0      NaN       NaN       NaN         FRO
# 872                 0      NaN       NaN       NaN         HGB
# 873                 0      NaN       NaN       NaN         HFC
# 874                 0      NaN       NaN       NaN         HHM
# 940                 0      NaN       NaN       NaN         HTE
#
#                          home_link  \
# 7                              NaN
# 51                             NaN
# 138                            NaN
# 164                            NaN
# 183                            NaN
# 218                            NaN
# 236                            NaN
# 237                            NaN
# 362                            NaN
# 390                            NaN
# 405  http://www.aeroclubsalta.com/
# 408                            NaN
# 412                            NaN
# 472                            NaN
# 509                            NaN
# 559                            NaN
# 585                            NaN
# 601                            NaN
# 608                            NaN
# 609                            NaN
# 663                            NaN
# 672                            NaN
# 872                            NaN
# 873                            NaN
# 874                            NaN
# 940                            NaN
#
#                                         wikipedia_link  \
# 7    https://en.wikipedia.org/wiki/Mart%C3%ADn_Migu...
# 51      https://en.wikipedia.org/wiki/Tartagal_Airport
# 138                                                NaN
# 164    https://en.wikipedia.org/wiki/Or%C3%A1n_Airport
# 183                                                NaN
# 218                                                NaN
# 236                                                NaN
# 237  https://es.wikipedia.org/wiki/Aer%C3%B3dromo_G...
# 362                                                NaN
# 390                                                NaN
# 405                                                NaN
# 408                                                NaN
# 412                                                NaN
# 472                                                NaN
# 509                                                NaN
# 559                                                NaN
# 585                                                NaN
# 601                                                NaN
# 608                                                NaN
# 609                                                NaN
# 663                                                NaN
# 672                                                NaN
# 872                                                NaN
# 873                                                NaN
# 874                                                NaN
# 940                                                NaN
#
#                                     keywords score               last_updated
# 7                                        NaN   750  2011-07-03T00:07:47+00:00
# 51                                       NaN   750  2025-02-20T01:01:25+00:00
# 138                                     SA22    50  2011-07-10T05:36:12+00:00
# 164                                      NaN   250  2024-05-16T20:11:54+00:00
# 183                                      NaN    50  2016-06-05T11:01:51+00:00
# 218                                      NaN    50  2016-06-03T12:21:46+00:00
# 236                                     SA01    50  2011-07-10T01:05:22+00:00
# 237                   SA02, Gilberto Lavaque    50  2024-03-12T17:07:51+00:00
# 362                                      NaN    50  2016-06-03T18:01:21+00:00
# 390                                      NaN    50  2016-06-03T19:02:22+00:00
# 405                                     SA74    50  2017-01-08T14:21:23+00:00
# 408  Ingenio, San, Isidro, Airstrip, Pista,     50  2024-10-22T02:41:39+00:00
# 412                                      NaN    50  2016-06-03T22:13:30+00:00
# 472                                      NaN    50  2011-07-09T12:24:56+00:00
# 509                                      NaN    50  2016-06-04T08:42:46+00:00
# 559                                      NaN    50  2011-02-11T21:43:52+00:00
# 585                                      NaN    50  2016-06-04T11:21:35+00:00
# 601                                      NaN    50  2018-05-06T14:34:20+00:00
# 608                                      NaN    50  2016-06-04T13:23:02+00:00
# 609                                      NaN    50  2018-05-05T15:36:39+00:00
# 663                                      NaN    50  2011-07-03T00:24:03+00:00
# 672                                      NaN    50  2011-07-14T01:38:43+00:00
# 872                                      NaN    25  2009-10-20T11:13:15+00:00
# 873                                      NaN    25  2009-10-20T11:13:17+00:00
# 874                                      NaN    25  2009-10-20T11:13:17+00:00
# 940                                      NaN     0  2024-11-26T12:30:54+00:00
#
# [26 rows x 24 columns]
